# %%
import os
import pandas as pd
import numpy as np
import re

# %%
top_dir = '/project/'
data_dir = os.path.join(top_dir, 'data')
raw_data_dir = os.path.join(data_dir, 'raw')
os.listdir(raw_data_dir)
# Out:
# ['supp_table1.xlsx', 'supp_table4.xlsx']

# %%
supp_table1 = pd.read_excel(os.path.join(raw_data_dir, 'supp_table1.xlsx'),
                           engine = 'openpyxl',
                           header = 1)
supp_table4 = pd.read_excel(os.path.join(raw_data_dir, 'supp_table4.xlsx'),
                           engine = 'openpyxl',
                           header = 1)

# %%
supp_table1
# Out:
#                                           Author (Year)  \
# 0                                                   NaN
# 1                                            Jie (2017)
# 2                                            Jie (2017)
# 3                                            Jie (2017)
# 4                                            Jie (2017)
# ...                                                 ...
# 4344                                          He (2017)
# 4345                                          He (2017)
# 4346                                          He (2017)
# 4347                                          He (2017)
# 4348  aACVD: Atherosclerotic Cardiovascular Disease....
#
#                                       Publication Title  \
# 0                                                   NaN
# 1     The gut microbiome in atherosclerotic cardiova...
# 2     The gut microbiome in atherosclerotic cardiova...
# 3     The gut microbiome in atherosclerotic cardiova...
# ...

# %%
supp_table4
# Out:
#      Author (Year)                                  Publication Title  \
# 0              NaN                                                NaN
# 1    Vaughn (2016)  Increased Intestinal Microbial Diversity follo...
# 2    Vaughn (2016)  Increased Intestinal Microbial Diversity follo...
# 3    Vaughn (2016)  Increased Intestinal Microbial Diversity follo...
# 4    Vaughn (2016)  Increased Intestinal Microbial Diversity follo...
# ..             ...                                                ...
# 750            NaN                                                NaN
# 751            NaN                                                NaN
# 752            NaN                                                NaN
# 753            NaN                                                NaN
# 754            NaN                                                NaN
#
#                         Journal Study Accession Sample Accession  \
# ...

# %%
supp_table1_clean = supp_table1.iloc[1:4348, :]
supp_table1_clean.keys()
# Out:
# Index(['Author (Year)', 'Publication Title', 'Journal', 'Study Accession',
#        'Sample Accession', 'Sequencing Platform', 'Library Layout',
#        'Subject Health Status', 'Phenotypea', 'Subject Meta-datab',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
cols_replace_table1 = np.logical_not(supp_table1.iloc[0,:].to_numpy().astype('str') == 'nan')
names_replace_table1 = supp_table1.iloc[0,:][cols_replace_table1]
table1_keynames = supp_table1_clean.keys().to_numpy()
table1_keynames[cols_replace_table1] = names_replace_table1
supp_table1_clean.columsn = table1_keynames
supp_table1_clean
# Out:
# /root/anaconda/envs/microbiome/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """
#      Author (Year)                                  Publication Title  \
# 1       Jie (2017)  The gut microbiome in atherosclerotic cardiova...
# 2       Jie (2017)  The gut microbiome in atherosclerotic cardiova...
# 3       Jie (2017)  The gut microbiome in atherosclerotic cardiova...
# 4       Jie (2017)  The gut microbiome in atherosclerotic cardiova...
# 5       Jie (2017)  The gut microbiome in atherosclerotic cardiova...
# ...            ...                                                ...
# 4343     He (2017)  Two distinct metacommunities characterize the ...
# 4344     He (2017)  Two distinct metacommunities characterize the ...
# 4345     He (2017)  Two distinct metacommunities characterize the ...
# ...

# %%
supp_table1_clean.columns
# Out:
# Index(['Author (Year)', 'Publication Title', 'Journal', 'Study Accession',
#        'Sample Accession', 'Sequencing Platform', 'Library Layout',
#        'Subject Health Status', 'Phenotypea', 'Age (Years)', 'Sex',
#        'BMI (kg/m²)', 'Fasting Blood Glucose (mmol/L)',
#        'Triglycerides (mmol/L)', 'LDL Cholesterol (mmol/L)',
#        'Cholesterol (mmol/L)', 'HDL Cholesterol (mmol/L)',
#        'Physical Exercise (Yes/No/Hours)', 'Smoker (Yes/No)',
#        'Dairy Product Consumption', 'Meat Consumption (Yes/No/Vegetarian)',
#        'Alcohol Consumption (Yes/No/Frequency)'],
#       dtype='object')

# %%
supp_table1_clean.columns
# Out:
# Index(['Author (Year)', 'Publication Title', 'Journal', 'Study Accession',
#        'Sample Accession', 'Sequencing Platform', 'Library Layout',
#        'Subject Health Status', 'Phenotypea', 'Age (Years)', 'Sex',
#        'BMI (kg/m²)', 'Fasting Blood Glucose (mmol/L)',
#        'Triglycerides (mmol/L)', 'LDL Cholesterol (mmol/L)',
#        'Cholesterol (mmol/L)', 'HDL Cholesterol (mmol/L)',
#        'Physical Exercise (Yes/No/Hours)', 'Smoker (Yes/No)',
#        'Dairy Product Consumption', 'Meat Consumption (Yes/No/Vegetarian)',
#        'Alcohol Consumption (Yes/No/Frequency)'],
#       dtype='object')

# %%
supp_table4_clean = supp_table4.iloc[2:680, :13]
supp_table4_clean.keys()
# Out:
# Index(['Author (Year)', 'Publication Title', 'Journal', 'Study Accession',
#        'Sample Accession', 'Sequencing Platform', 'Library Layout',
#        'Subject Health Status', 'Phenotype', 'Subject Meta-dataa',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
supp_table4_clean
# Out:
#      Author (Year)                                  Publication Title  \
# 2    Vaughn (2016)  Increased Intestinal Microbial Diversity follo...
# 3    Vaughn (2016)  Increased Intestinal Microbial Diversity follo...
# 4    Vaughn (2016)  Increased Intestinal Microbial Diversity follo...
# 5    Vaughn (2016)  Increased Intestinal Microbial Diversity follo...
# 6    Vaughn (2016)  Increased Intestinal Microbial Diversity follo...
# ..             ...                                                ...
# 675  Current study                                      Current study
# 676  Current study                                      Current study
# 677  Current study                                      Current study
# 678  Current study                                      Current study
# 679  Current study                                      Current study
#
#                         Journal Study Accession Sample Accession  \
# ...

# %%
preproc_data_dir = os.path.join(data_dir, 'preprocessed')
output_dir = os.path.join(preproc_data_dir, 'preproc_tables')
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    
supp_table1_clean.to_csv(os.path.join(output_dir, 'supp_table1_clean.csv'))
supp_table4_clean.to_csv(os.path.join(output_dir, 'supp_table4_clean.csv'))
