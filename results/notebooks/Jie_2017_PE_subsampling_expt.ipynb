# %% [markdown]
# # Correlation Analysis of Species Profiles
#
# ## Overview:
#
# We want to see if subsampled reads can preserve information content at depths of 50K reads or lower. We do this as follows
#
# 1. Number of features detected in sequencing experiment
# 2. Overlap (Jaccard Index) of features detected in sequencing experiment, correlation of union of nonzero features across different depths
#
#
# ## Relies on:
#
# * workflow/cmd.sh
# * workflow/Snakefile.subsample_kraken2_wf
# * workflow/kraken2_wf_config.yaml
# * workflow/Snakefile.subsample_wf

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import jaccard
from scipy.stats import pearsonr
import sys
import os
import re
import seaborn as sns
from matplotlib import pyplot as plt
sys.path.insert(0, '/project/src/')
from util.species_name_parser import get_tax_rank

# %% [markdown]
# # Data Munging

# %%
root_dir = '/project'
top_data_dir = os.path.join(root_dir, 'workflow/PE_subsampling_experiments/insilico_depth_experiment')
os.listdir(top_data_dir)
# Out:
# ['kraken2_PE_1K',
#  'kraken2_PE_500',
#  'kraken2_PE_50K',
#  'kraken2_PE_100K',
#  'kraken2_PE_10K',
#  'kraken2_PE_5K',
#  'kraken2_PE_1M',
#  'kraken2_PE_5M',
#  'kraken2_PE_500K',
#  'kraken2_PE_25K',
#  'kraken2_PE_10M']

# %%
data_subdirs = np.array(os.listdir(top_data_dir))
kraken2_subdirs = np.sort(data_subdirs[np.array([len(re.findall('kraken2_PE_[0-9]+[KM]*$', x)) > 0 for x in data_subdirs])])
kraken2_subdirs
# Out:
# array(['kraken2_PE_100K', 'kraken2_PE_10K', 'kraken2_PE_10M',
#        'kraken2_PE_1K', 'kraken2_PE_1M', 'kraken2_PE_25K',
#        'kraken2_PE_500', 'kraken2_PE_500K', 'kraken2_PE_50K',
#        'kraken2_PE_5K', 'kraken2_PE_5M'], dtype='<U15')

# %%
kraken2_depths = []
for x in kraken2_subdirs:
    suffix = re.findall('[0-9]+[KM]*$', x)[0]
    trailing_0s = ''
    if re.search('K$', suffix):
        # 1000s of reads
        trailing_0s += '000'
    elif re.search('M$', suffix):
        # millions of reads
        trailing_0s += '000000'
    
    num_use = re.findall('[0-9]+', suffix)[0]
    kraken2_depths.append(int(num_use + trailing_0s))
    
kraken2_depths = np.array(kraken2_depths)
kraken2_depths
# Out:
# array([  100000,    10000, 10000000,     1000,  1000000,    25000,
#             500,   500000,    50000,     5000,  5000000])

# %%
pipeline_metadata = pd.DataFrame({'pipeline_run': kraken2_subdirs, 'depth': kraken2_depths})
pipeline_metadata = pipeline_metadata.sort_values('depth')
pipeline_metadata
# Out:
#        pipeline_run     depth
# 6    kraken2_PE_500       500
# 3     kraken2_PE_1K      1000
# 9     kraken2_PE_5K      5000
# 1    kraken2_PE_10K     10000
# 5    kraken2_PE_25K     25000
# 8    kraken2_PE_50K     50000
# 0   kraken2_PE_100K    100000
# 7   kraken2_PE_500K    500000
# 4     kraken2_PE_1M   1000000
# 10    kraken2_PE_5M   5000000
# 2    kraken2_PE_10M  10000000

# %%
def get_matrix(df):
    """
    Get a numeric matrix from data frame
    """
    matrix_cols = np.setdiff1d(df.columns.to_numpy(), ['filename', 'pipeline_run', 'run_acc', 'total_feats', 'depth'])
    mat = df.loc[:, matrix_cols].to_numpy().astype('float32')
    return mat

def get_accs(df):
    """
    Get Run Accessions from DataFrame
    """
    fastq_file_names = df['filename'].to_numpy().astype('str')
    # get run accessions. This will be important for running correlation + overlap comparisons
    run_acc = []
    for x in fastq_file_names:
        m = re.match('^[A-Z]{3}[0-9]+', x)
        if m:
            run_acc.append(m.group(0))
        else:
            raise ValueError('Unexpected run accession {}'.format(x))
            
    df['run_acc'] = np.array(run_acc)
    return df

def get_total_feats(df):
    """
    Get total number of nonzero, non-NA features
    """
    mat = get_matrix(df)
    total_feats = np.array([np.sum(mat[i, :].flatten() > 0) for i in range(mat.shape[0])])
    df['total_feats'] = total_feats
    return df

def load_file(freq_file):
    file_data = pd.read_csv(freq_file)
    file_data = get_accs(file_data)
    file_data = get_total_feats(file_data)
    
    return file_data

# %%
# load and merge data from all kraken2 pipeline runs
m = 0
for run in pipeline_metadata['pipeline_run']:
    fpath = os.path.join(top_data_dir, run, 'matrix/freq_mat.csv')
    loaded_df = load_file(fpath)
    # add depth to metadata
    loaded_df['depth'] = np.repeat(pipeline_metadata['depth'][pipeline_metadata['pipeline_run'] == run].to_numpy(), loaded_df.shape[0])
    # forces non-duplicate identifier. directories cannot be duplicated, nor can filenames within a directory
    loaded_df['depth_file'] = np.array([str(loaded_df['depth'][i]) + '_' + loaded_df['filename'][i] for i in range(loaded_df.shape[0])])
    melted_df = pd.melt(loaded_df, id_vars='depth_file')
    if m == 0:
        combined_melted_df = melted_df
        m += 1
    else:
        combined_melted_df = combined_melted_df.append(melted_df)
        
melted_df
# Out:
#                                                 depth_file  variable  \
# 0        10000000_ERR2017411_seqt.subsampled_1_kneaddat...  filename
# 1        10000000_ERR2017412_seqt.subsampled_1_kneaddat...  filename
# 2        10000000_ERR2017413_seqt.subsampled_1_kneaddat...  filename
# 3        10000000_ERR2017414_seqt.subsampled_1_kneaddat...  filename
# 4        10000000_ERR2017415_seqt.subsampled_1_kneaddat...  filename
# ...                                                    ...       ...
# 3598843  10000000_ERR2017809_seqt.subsampled_1_kneaddat...     depth
# 3598844  10000000_ERR2017810_seqt.subsampled_1_kneaddat...     depth
# 3598845  10000000_ERR2017813_seqt.subsampled_1_kneaddat...     depth
# 3598846  10000000_ERR2017814_seqt.subsampled_1_kneaddat...     depth
# 3598847  10000000_ERR2017815_seqt.subsampled_1_kneaddat...     depth
#
#                                                      value
# 0        ERR2017411_seqt.subsampled_1_kneaddata_paired_...
# 1        ERR2017412_seqt.subsampled_1_kneaddata_paired_...
# 2        ERR2017413_seqt.subsampled_1_kneaddata_paired_...
# 3        ERR2017414_seqt.subsampled_1_kneaddata_paired_...
# 4        ERR2017415_seqt.subsampled_1_kneaddata_paired_...
# ...                                                    ...
# 3598843                                           10000000
# 3598844                                           10000000
# 3598845                                           10000000
# 3598846                                           10000000
# 3598847                                           10000000
#
# [3598848 rows x 3 columns]

# %%
combined_df = pd.pivot(combined_melted_df, index='depth_file', columns='variable', values='value')
combined_df
# Out:
# variable                                                                                                         Homo sapiens  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                               0.01
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                               0.02
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                               0.01
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                               0.01
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                               0.01
# ...                                                                                               ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                                NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                                NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                                NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                                NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                               0.48
#
# variable                                                                                     Brassica napus  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                                NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                                NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                                NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                                NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                                NaN
# ...                                                                                               ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                                NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                                NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                                NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                                NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                                NaN
#
# variable                                                                     BtRf-AlphaCoV/YN2012  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                            NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                            NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                            NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                            NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                            NaN
# ...                                                                                           ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                            NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                            NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                            NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                            NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                            NaN
#
# variable                                                                     Coronavirus AcCoV-JC34  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                              NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                              NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                              NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                              NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                              NaN
# ...                                                                                             ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                              NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                              NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                              NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                              NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                              NaN
#
# variable                                                                   Alphacoronavirus 1  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                        NaN
# ...                                                                                       ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                        NaN
#
# variable                                                                   Alphamesonivirus 1  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                        NaN
# ...                                                                                       ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                        NaN
#
# variable                                                                   Alphamesonivirus 2  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                        NaN
# ...                                                                                       ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                        NaN
#
# variable                                                                   Alphamesonivirus 4  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                        NaN
# ...                                                                                       ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                        NaN
#
# variable                                                                   Alphamesonivirus 6  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                        NaN
# ...                                                                                       ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                        NaN
#
# variable                                                                   Alphamesonivirus 7  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                        NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                        NaN
# ...                                                                                       ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                        NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                        NaN
#
# variable                                            ...  \
# depth_file                                          ...
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...  ...
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...  ...
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...  ...
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...  ...
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...  ...
# ...                                                 ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...  ...
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...  ...
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...  ...
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...  ...
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...  ...
#
# variable                                                 Sewage-associated circular DNA virus-4  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                          NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                          NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                          NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                          NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                          NaN
# ...                                                                                         ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                          NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                          NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                          NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                          NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                          NaN
#
# variable                                                 Thika virus  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...               NaN
# ...                                                              ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...               NaN
#
# variable                                                 Tunis virus  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...               NaN
# ...                                                              ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...               NaN
#
# variable                                                 Wabat virus  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...               NaN
# ...                                                              ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...               NaN
#
# variable                                                 Zirqa virus  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...               NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...               NaN
# ...                                                              ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...               NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...               NaN
#
# variable                                                 uncultured Mediterranean phage  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...                                  NaN
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...                                  NaN
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...                                  NaN
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...                                  NaN
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...                                  NaN
# ...                                                                                 ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...                                  NaN
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...                                  NaN
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...                                  NaN
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...                                  NaN
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...                                  NaN
#
# variable                                               depth  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...  10000000
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...  10000000
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...  10000000
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...  10000000
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...  10000000
# ...                                                      ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...       500
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...       500
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...       500
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...       500
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...       500
#
# variable                                                                                     filename  \
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...  ERR2017411_seqt.subsampled_1_kneaddata_paired_...
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...  ERR2017412_seqt.subsampled_1_kneaddata_paired_...
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...  ERR2017413_seqt.subsampled_1_kneaddata_paired_...
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...  ERR2017414_seqt.subsampled_1_kneaddata_paired_...
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...  ERR2017415_seqt.subsampled_1_kneaddata_paired_...
# ...                                                                                               ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...  ERR2017809_seqt.subsampled_1_kneaddata_paired_...
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...  ERR2017810_seqt.subsampled_1_kneaddata_paired_...
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...  ERR2017813_seqt.subsampled_1_kneaddata_paired_...
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...  ERR2017814_seqt.subsampled_1_kneaddata_paired_...
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...  ERR2017815_seqt.subsampled_1_kneaddata_paired_...
#
# variable                                               run_acc total_feats
# depth_file
# 10000000_ERR2017411_seqt.subsampled_1_kneaddata...  ERR2017411         125
# 10000000_ERR2017412_seqt.subsampled_1_kneaddata...  ERR2017412         123
# 10000000_ERR2017413_seqt.subsampled_1_kneaddata...  ERR2017413         113
# 10000000_ERR2017414_seqt.subsampled_1_kneaddata...  ERR2017414         108
# 10000000_ERR2017415_seqt.subsampled_1_kneaddata...  ERR2017415         111
# ...                                                        ...         ...
# 500_ERR2017809_seqt.subsampled_1_kneaddata_pair...  ERR2017809          48
# 500_ERR2017810_seqt.subsampled_1_kneaddata_pair...  ERR2017810          45
# 500_ERR2017813_seqt.subsampled_1_kneaddata_pair...  ERR2017813          34
# 500_ERR2017814_seqt.subsampled_1_kneaddata_pair...  ERR2017814          47
# 500_ERR2017815_seqt.subsampled_1_kneaddata_pair...  ERR2017815          42
#
# [4224 rows x 9612 columns]

# %%
# combined_df.to_pickle("PE_insilico_depth_combined_df.pkl")
# combined_df.to_csv("PE_insilico_depth_combined_df.csv")

# %% [markdown]
# # I. Total Nonzero Features Per Sample

# %%
f = plt.figure(figsize=(10,10))
ax = sns.boxplot(data=combined_df, x='depth', y='total_feats')
f.show()

# %% [markdown]
# # Overlap + Correlation of Features At Varying Depths

# %%
depths_use = combined_df.sort_values('depth')['depth'].unique()
unique_samples = combined_df['run_acc'].unique()
ten_M_idx = (combined_df['depth'] == 10e6).to_numpy()
data_mat = get_matrix(combined_df)
data_mat.shape
# Out:
# (4224, 9608)

# %%
stats_dict = {'depth': [], 'run_acc': [], 'jaccard': [], 'cor': [], 'feats_at_depth': [],
              'feats_at_10M': [], 'union_feats': [], 'common_feats': []}

for i in range(0, len(depths_use) - 1):
    depth_i = depths_use[i]
    depth_i_idx = (combined_df['depth'] == depth_i).to_numpy()
    for s in unique_samples:
        s_idx = (combined_df['run_acc'] == s).to_numpy()
        s_i_idx = np.logical_and(depth_i_idx, s_idx)
        if not np.sum(s_i_idx) == 1:
            assert False
        s_i_vals = data_mat[s_i_idx, :].flatten()
        # set nan values to 0
        s_i_vals[np.logical_not(s_i_vals > 0)] = 0.
        
        s_10M_idx = np.logical_and(ten_M_idx, s_idx)
        if not np.sum(s_10M_idx) == 1:
            assert False
        s_10M_vals = data_mat[s_10M_idx, :].flatten()
        s_10M_vals[np.logical_not(s_10M_vals > 0)] = 0.
        # calculate overlap with feats at given depth with feats at 10M reads
        s_i_feats = s_i_vals > 0
        s_10M_feats = s_10M_vals > 0
        s_i_overlap = jaccard(s_i_feats, s_10M_feats)
        # calculate correlation across union of nonzero features
        union_feats = np.logical_or(s_i_feats, s_10M_feats)
        common_feats = np.logical_and(s_i_feats, s_10M_feats)
        s_i_cor, _ = pearsonr(s_i_vals[common_feats], s_10M_vals[common_feats])
        # store values
        stats_dict['depth'].append(depth_i)
        stats_dict['run_acc'].append(s)
        stats_dict['jaccard'].append(s_i_overlap)
        stats_dict['cor'].append(s_i_cor)
        stats_dict['feats_at_depth'].append(np.sum(s_i_feats))
        stats_dict['feats_at_10M'].append(np.sum(s_10M_feats))
        stats_dict['union_feats'].append(np.sum(union_feats))
        stats_dict['common_feats'].append(np.sum(common_feats))
        
stats_df = pd.DataFrame(stats_dict)

# %%
stats_df
# Out:
#         depth     run_acc   jaccard       cor  feats_at_depth  feats_at_10M  \
# 0         500  ERR2017411  0.740458  0.980689              40           125
# 1         500  ERR2017412  0.701613  0.803916              38           123
# 2         500  ERR2017413  0.709402  0.971429              38           113
# 3         500  ERR2017414  0.719298  0.988650              38           108
# 4         500  ERR2017415  0.730435  0.953390              35           111
# ...       ...         ...       ...       ...             ...           ...
# 3835  5000000  ERR2017809  0.010811  0.999979             184           184
# 3836  5000000  ERR2017810  0.022059  0.999998             134           135
# 3837  5000000  ERR2017813  0.005952  0.999992             167           168
# 3838  5000000  ERR2017814  0.037500  0.999997             155           159
# 3839  5000000  ERR2017815  0.034014  0.999985             146           143
#
#       union_feats  common_feats
# 0             131            34
# 1             124            37
# 2             117            34
# 3             114            32
# 4             115            31
# ...           ...           ...
# 3835          185           183
# 3836          136           133
# 3837          168           167
# 3838          160           154
# 3839          147           142
#
# [3840 rows x 8 columns]

# %%
# size of union of nonzero features between 10 million read depth and other read depths
f = plt.figure(figsize=(10,10))
ax = sns.boxplot(data=stats_df, x='depth', y='union_feats')
f.show()

# %%
# size of intersection of features between 10 million read depth and other read depths
f = plt.figure(figsize=(10,10))
ax = sns.boxplot(data=stats_df, x='depth', y='common_feats')
f.show()

# %%
# jaccard distance of nonzero feature sets for depth of 10 million and other depths (other depth listed on x axis)
# 1.0 = no overlap, 0.0 = perfect overlap
f = plt.figure(figsize=(10,10))
ax = sns.boxplot(data=stats_df, x='depth', y='jaccard')
f.show()

# %%
# correlation of common feature set for 10 million read depth and other read depths.
# at each depth, pearson's correlation is calculated between 10 million read depth and lower read depth for given pair's intersection
# of nonzero features
f = plt.figure(figsize=(10,10))
ax = sns.boxplot(data=stats_df, x='depth', y='cor')
f.show()
