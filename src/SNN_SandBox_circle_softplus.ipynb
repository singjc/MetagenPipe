# %%
from sklearn import model_selection
from sklearn.preprocessing import OneHotEncoder
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
import os
import torch
import numpy as np
import pandas as pd
from MicroBiome import MicroBiomeDataSet, Trainer, TrainTester, MultiTrainTester
from SNN import FeedForward, SiameseDataSet, SiameseModel, seed_everything
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random

# Ignore warning messages
if True:
    import warnings
    warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
from sklearn.datasets import make_circles

np.random.seed(42)

X, y = make_circles(n_samples=4000, factor=.3, noise=0.25)
OneHot = OneHotEncoder(sparse=False)
y = OneHot.fit_transform(y.reshape((y.shape[0], 1)))

# %%
y
# Out:
# array([[1., 0.],
#        [0., 1.],
#        [1., 0.],
#        ...,
#        [1., 0.],
#        [0., 1.],
#        [0., 1.]])

# %%
y.shape
# Out:
# (4000, 2)

# %%
np.sum(y, axis=0)
# Out:
# array([2000., 2000.])

# %%
sns.displot(X)

# %%
# Test Effect of making X non-negative
# X = X + 2

# %% [markdown]
# # Define and Train Model

# %%
seed_everything(69)

# %%
MyFeedForward = FeedForward(2, [3, 2], activation='softplus')

# %%
MyFeedForward
# Out:
# FeedForward(
#   (layers): ModuleList(
#     (0): Linear(in_features=2, out_features=3, bias=True)
#     (1): Linear(in_features=3, out_features=2, bias=True)
#   )
# )

# %%
MySNN = SiameseModel(MyFeedForward, predict_unknown = False, class_min_train=5, 
                     n_example_predict=10, learning_rate=1.0e-3, num_epochs = 20, batch_size = 1000, rand_seed=142)

# %%
# list(MySNN.logistic.parameters()) + list(MySNN.model.parameters())

# %%
MyTrainer = Trainer(model = MySNN, scale_X = False, use_pca = False, n_components = 2)

# %%
MyTrainTester = TrainTester(MyTrainer, metrics.accuracy_score)

# %%
n_splits = 5
MyMultiTrainTester = MultiTrainTester(MyTrainTester, n_splits=n_splits)

# %%
MyMultiTrainTester.train(X, y)
# Out:
# Running for split 1 of 5
# Training Encoder
# #########################################
# Epoch 1 of 20
# __Training__
# 2021-03-08 03:23:34
# MEAN LOSS: 0.744764224243164
# __Validation__
# 2021-03-08 03:23:35
# MEAN LOSS: 0.7329370067744079
# #########################################
# Epoch 2 of 20
# __Training__
# 2021-03-08 03:23:35
# MEAN LOSS: 0.7240037567138672
# __Validation__
# 2021-03-08 03:23:35
# MEAN LOSS: 0.7158092151988636
# #########################################
# Epoch 3 of 20
# __Training__
# 2021-03-08 03:23:35
# MEAN LOSS: 0.7105747741699219
# __Validation__
# 2021-03-08 03:23:36
# MEAN LOSS: 0.7054177051616295
# #########################################
# Epoch 4 of 20
# __Training__
# 2021-03-08 03:23:36
# MEAN LOSS: 0.702914486694336
# __Validation__
# 2021-03-08 03:23:36
# MEAN LOSS: 0.6998513785704742
# #########################################
# Epoch 5 of 20
# __Training__
# 2021-03-08 03:23:36
# MEAN LOSS: 0.6990660339355469
# __Validation__
# 2021-03-08 03:23:36
# MEAN LOSS: 0.6972269767259929
# #########################################
# Epoch 6 of 20
# __Training__
# 2021-03-08 03:23:36
# MEAN LOSS: 0.6973412475585937
# __Validation__
# 2021-03-08 03:23:37
# MEAN LOSS: 0.6961042677143691
# #########################################
# Epoch 7 of 20
# __Training__
# 2021-03-08 03:23:37
# MEAN LOSS: 0.6965894500732421
# __Validation__
# 2021-03-08 03:23:37
# MEAN LOSS: 0.6956121271306818
# #########################################
# Epoch 8 of 20
# __Training__
# 2021-03-08 03:23:37
# MEAN LOSS: 0.6962016967773438
# __Validation__
# 2021-03-08 03:23:38
# MEAN LOSS: 0.6953441849922297
# #########################################
# Epoch 9 of 20
# __Training__
# 2021-03-08 03:23:38
# MEAN LOSS: 0.6959332824707031
# __Validation__
# 2021-03-08 03:23:38
# MEAN LOSS: 0.6951526466733587
# #########################################
# Epoch 10 of 20
# __Training__
# 2021-03-08 03:23:38
# MEAN LOSS: 0.6957081878662109
# __Validation__
# 2021-03-08 03:23:39
# MEAN LOSS: 0.6949922302410905
# #########################################
# Epoch 11 of 20
# __Training__
# 2021-03-08 03:23:39
# MEAN LOSS: 0.6955060119628906
# __Validation__
# 2021-03-08 03:23:39
# MEAN LOSS: 0.6948490640690046
# #########################################
# Epoch 12 of 20
# __Training__
# 2021-03-08 03:23:39
# MEAN LOSS: 0.6953205627441407
# __Validation__
# 2021-03-08 03:23:39
# MEAN LOSS: 0.694718052737891
# #########################################
# Epoch 13 of 20
# __Training__
# 2021-03-08 03:23:39
# MEAN LOSS: 0.6951489318847657
# __Validation__
# 2021-03-08 03:23:40
# MEAN LOSS: 0.6945969575595254
# #########################################
# Epoch 14 of 20
# __Training__
# 2021-03-08 03:23:40
# MEAN LOSS: 0.694989340209961
# __Validation__
# 2021-03-08 03:23:40
# MEAN LOSS: 0.6944846111198034
# #########################################
# Epoch 15 of 20
# __Training__
# 2021-03-08 03:23:40
# MEAN LOSS: 0.6948405303955079
# __Validation__
# 2021-03-08 03:23:41
# MEAN LOSS: 0.6943802030959932
# #########################################
# Epoch 16 of 20
# __Training__
# 2021-03-08 03:23:41
# MEAN LOSS: 0.6947015594482422
# __Validation__
# 2021-03-08 03:23:41
# MEAN LOSS: 0.6942831429139008
# #########################################
# Epoch 17 of 20
# __Training__
# 2021-03-08 03:23:41
# MEAN LOSS: 0.6945715606689453
# __Validation__
# 2021-03-08 03:23:41
# MEAN LOSS: 0.6941927987964812
# #########################################
# Epoch 18 of 20
# __Training__
# 2021-03-08 03:23:42
# MEAN LOSS: 0.6944498474121094
# __Validation__
# 2021-03-08 03:23:42
# MEAN LOSS: 0.6941087175123762
# #########################################
# Epoch 19 of 20
# __Training__
# 2021-03-08 03:23:42
# MEAN LOSS: 0.6943357940673828
# __Validation__
# 2021-03-08 03:23:42
# MEAN LOSS: 0.694030432095944
# #########################################
# Epoch 20 of 20
# __Training__
# 2021-03-08 03:23:42
# MEAN LOSS: 0.6942288177490235
# __Validation__
# 2021-03-08 03:23:43
# MEAN LOSS: 0.6939575785886695
# #########################################
# Finished
# 2021-03-08 03:23:43
# Running for split 2 of 5
# Training Encoder
# #########################################
# Epoch 1 of 20
# __Training__
# 2021-03-08 03:23:43
# MEAN LOSS: 0.7452876586914062
# __Validation__
# 2021-03-08 03:23:44
# MEAN LOSS: 0.7352901153152425
# #########################################
# Epoch 2 of 20
# __Training__
# 2021-03-08 03:23:44
# MEAN LOSS: 0.7239217681884765
# __Validation__
# 2021-03-08 03:23:44
# MEAN LOSS: 0.7176938610609108
# #########################################
# Epoch 3 of 20
# __Training__
# __Validation__
# 2021-03-08 03:24:19
# MEAN LOSS: 0.6934923846693751
# #########################################
# Finished
# 2021-03-08 03:24:19

# %%
scores_df = pd.DataFrame({'score': MyMultiTrainTester.train_scores, 'stage' : np.repeat('train', n_splits)})
scores_df = scores_df.append(pd.DataFrame({'score': MyMultiTrainTester.test_scores, 'stage' : np.repeat('test', n_splits)}))
scores_df
# Out:
#       score  stage
# 0  0.685000  train
# 1  0.731563  train
# 2  0.640312  train
# 3  0.671250  train
# 4  0.654375  train
# 0  0.701250   test
# 1  0.743750   test
# 2  0.595000   test
# 3  0.668750   test
# 4  0.636250   test

# %%
sns.boxplot(data = scores_df, x = 'stage', y = 'score')
# Out:
# <AxesSubplot:xlabel='stage', ylabel='score'>

# %%
MyMultiTrainTester.plot_class_freq(normalize=True)

# %%
MyMultiTrainTester.plot_confusion(normalize=True)

# %%
for i, trainer in enumerate(MyMultiTrainTester.TrainerList):
    plt.figure(i)
    print(sns.lineplot(data=trainer.model.TrainStats, x='epoch', y='mean_loss', hue = 'stage'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ### Examine Data In Encoded Space

# %%
Trainer_use = MyMultiTrainTester.TrainerList[0]

# %%
X_transform = Trainer_use.transform_X(X)

# %%
X_encoded = Trainer_use.model.model.forward(torch.from_numpy(X_transform).to(torch.float32)).detach().numpy()

# %%
# X_encoded = MyFeedForward.forward(torch.from_numpy(X_transform).to(torch.float32)).detach().numpy()

# %%
X_encoded.shape
# Out:
# (4000, 2)

# %%
y_label = Trainer_use.model.one_hot.inverse_transform(y).astype('str')

# %%
y_pred = Trainer_use.model.predict(X_transform)
y_pred = Trainer_use.model.one_hot.inverse_transform(y_pred).astype('str')

# %%
X_enc_df = pd.DataFrame(X_encoded, columns = ['X' + str(i+1) for i in range(X_encoded.shape[1])])
X_enc_df['y'] = y_label
X_enc_df['y_pred'] = y_pred

# %%
X_enc_df
# Out:
#             X1        X2  y y_pred
# 0     0.482816  0.626254  0      1
# 1     0.433041  0.705918  1      1
# 2     0.530354  0.643749  0      0
# 3     0.365990  0.705280  1      1
# 4     0.524745  0.679875  1      0
# ...        ...       ... ..    ...
# 3995  0.572366  0.673893  0      0
# 3996  0.584217  0.686068  0      0
# 3997  0.599162  0.657487  0      0
# 3998  0.468542  0.705917  1      1
# 3999  0.536513  0.680125  1      0
#
# [4000 rows x 4 columns]

# %%
sns.displot(data=X_enc_df, x='X1', hue='y')

# %%
sns.displot(data=X_enc_df, x='X2', hue='y')

# %%
def do_plot(df, x, y, hue):
    if x in df.columns and y in df.columns and hue in df.columns:
        sns.scatterplot(data=df, x=x, y=y, hue = hue)

# %%
do_plot(X_enc_df, 'X1', 'X2', 'y')

# %%
do_plot(X_enc_df, 'X1', 'X2', 'y_pred')

# %%
do_plot(X_enc_df, 'X2', 'X3', 'y')

# %%
do_plot(X_enc_df, 'X3', 'X4', 'y')

# %% [markdown]
# ### Examine Data In Original Space

# %%
X_df = pd.DataFrame(X, columns = ['X1', 'X2'])
X_df['y'] = y_label

# %%
sns.scatterplot(data=X_df, x='X1', y='X2', hue = 'y')
# Out:
# <AxesSubplot:xlabel='X1', ylabel='X2'>
