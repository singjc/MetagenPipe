# %%
from sklearn import model_selection
from sklearn.preprocessing import OneHotEncoder
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
import os
import torch
import numpy as np
import pandas as pd
from MicroBiome import MicroBiomeDataSet, Trainer, TrainTester, MultiTrainTester
from SNN import FeedForward, SiameseDataSet, SiameseModel, seed_everything
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random

# Ignore warning messages
if True:
    import warnings
    warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
from sklearn.datasets import make_circles

np.random.seed(42)

X, y = make_circles(n_samples=4000, factor=.3, noise=0.25)
OneHot = OneHotEncoder(sparse=False)
y = OneHot.fit_transform(y.reshape((y.shape[0], 1)))

# %%
y
# Out:
# array([[1., 0.],
#        [0., 1.],
#        [1., 0.],
#        ...,
#        [1., 0.],
#        [0., 1.],
#        [0., 1.]])

# %%
y.shape
# Out:
# (4000, 2)

# %%
np.sum(y, axis=0)
# Out:
# array([2000., 2000.])

# %%
sns.displot(X)

# %%
# Test Effect of making X non-negative
# X = X + 2

# %% [markdown]
# # Define and Train Model

# %%
seed_everything(69)

# %%
MyFeedForward = FeedForward(2, [3, 2], activation='softplus')

# %%
MyFeedForward
# Out:
# FeedForward(
#   (layers): ModuleList(
#     (0): Linear(in_features=2, out_features=3, bias=True)
#     (1): Linear(in_features=3, out_features=2, bias=True)
#   )
# )

# %%
MySNN = SiameseModel(MyFeedForward, predict_unknown = False, class_min_train=5, 
                     n_example_predict=10, learning_rate=1.0e-3, num_epochs = 20, batch_size = 1000, rand_seed=142)

# %%
# list(MySNN.logistic.parameters()) + list(MySNN.model.parameters())

# %%
MyTrainer = Trainer(model = MySNN, scale_X = False, use_pca = False, n_components = 2)

# %%
MyTrainTester = TrainTester(MyTrainer, metrics.accuracy_score)

# %%
n_splits = 5
MyMultiTrainTester = MultiTrainTester(MyTrainTester, n_splits=n_splits)

# %%
MyMultiTrainTester.train(X, y)
# Out:
# Running for split 1 of 5
# Training Encoder
# #########################################
# Epoch 1 of 20
# __Training__
# 2021-03-08 04:17:53
# MEAN LOSS: 0.7220813934326172
# __Validation__
# 2021-03-08 04:17:53
# MEAN LOSS: 0.7170103813054646
# #########################################
# Epoch 2 of 20
# __Training__
# 2021-03-08 04:17:53
# MEAN LOSS: 0.716451889038086
# __Validation__
# 2021-03-08 04:17:54
# MEAN LOSS: 0.712176552127869
# #########################################
# Epoch 3 of 20
# __Training__
# 2021-03-08 04:17:54
# MEAN LOSS: 0.711835498046875
# __Validation__
# 2021-03-08 04:17:54
# MEAN LOSS: 0.7082468783072154
# #########################################
# Epoch 4 of 20
# __Training__
# 2021-03-08 04:17:54
# MEAN LOSS: 0.7080619476318359
# __Validation__
# 2021-03-08 04:17:54
# MEAN LOSS: 0.7050529431910476
# #########################################
# Epoch 5 of 20
# __Training__
# 2021-03-08 04:17:55
# MEAN LOSS: 0.7049755920410157
# __Validation__
# 2021-03-08 04:17:55
# MEAN LOSS: 0.7024648891280729
# #########################################
# Epoch 6 of 20
# __Training__
# 2021-03-08 04:17:55
# MEAN LOSS: 0.7024602600097656
# __Validation__
# 2021-03-08 04:17:55
# MEAN LOSS: 0.7003869263574307
# #########################################
# Epoch 7 of 20
# __Training__
# 2021-03-08 04:17:55
# MEAN LOSS: 0.7004287322998047
# __Validation__
# 2021-03-08 04:17:56
# MEAN LOSS: 0.6987441686978757
# #########################################
# Epoch 8 of 20
# __Training__
# 2021-03-08 04:17:56
# MEAN LOSS: 0.6988111083984375
# __Validation__
# 2021-03-08 04:17:56
# MEAN LOSS: 0.6974729920807022
# #########################################
# Epoch 9 of 20
# __Training__
# 2021-03-08 04:17:56
# MEAN LOSS: 0.6975471374511719
# __Validation__
# 2021-03-08 04:17:57
# MEAN LOSS: 0.6965126085667649
# #########################################
# Epoch 10 of 20
# __Training__
# 2021-03-08 04:17:57
# MEAN LOSS: 0.6965798767089844
# __Validation__
# 2021-03-08 04:17:57
# MEAN LOSS: 0.6958043933665827
# #########################################
# Epoch 11 of 20
# __Training__
# 2021-03-08 04:17:57
# MEAN LOSS: 0.6958536254882812
# __Validation__
# 2021-03-08 04:17:58
# MEAN LOSS: 0.6952873593938984
# #########################################
# Epoch 12 of 20
# __Training__
# 2021-03-08 04:17:58
# MEAN LOSS: 0.6953125549316406
# __Validation__
# 2021-03-08 04:17:58
# MEAN LOSS: 0.6949040698747609
# #########################################
# Epoch 13 of 20
# __Training__
# 2021-03-08 04:17:58
# MEAN LOSS: 0.6949048095703125
# __Validation__
# 2021-03-08 04:17:59
# MEAN LOSS: 0.6946079312521096
# #########################################
# Epoch 14 of 20
# __Training__
# 2021-03-08 04:17:59
# MEAN LOSS: 0.6945886169433594
# __Validation__
# 2021-03-08 04:17:59
# MEAN LOSS: 0.6943667091623713
# #########################################
# Epoch 15 of 20
# __Training__
# 2021-03-08 04:17:59
# MEAN LOSS: 0.6943344757080078
# __Validation__
# 2021-03-08 04:18:00
# MEAN LOSS: 0.6941624254283338
# #########################################
# Epoch 16 of 20
# __Training__
# 2021-03-08 04:18:00
# MEAN LOSS: 0.6941248474121093
# __Validation__
# 2021-03-08 04:18:00
# MEAN LOSS: 0.6939881236353616
# #########################################
# Epoch 17 of 20
# __Training__
# 2021-03-08 04:18:00
# MEAN LOSS: 0.6939495178222657
# __Validation__
# 2021-03-08 04:18:01
# MEAN LOSS: 0.6938361057175053
# #########################################
# Epoch 18 of 20
# __Training__
# 2021-03-08 04:18:01
# MEAN LOSS: 0.6937987915039062
# __Validation__
# 2021-03-08 04:18:01
# MEAN LOSS: 0.6937001775128685
# #########################################
# Epoch 19 of 20
# __Training__
# 2021-03-08 04:18:01
# MEAN LOSS: 0.6936670288085938
# __Validation__
# 2021-03-08 04:18:01
# MEAN LOSS: 0.6935783956203238
# #########################################
# Epoch 20 of 20
# __Training__
# 2021-03-08 04:18:02
# MEAN LOSS: 0.6935507354736328
# __Validation__
# 2021-03-08 04:18:02
# MEAN LOSS: 0.6934677728331915
# #########################################
# Finished
# 2021-03-08 04:18:02
# Running for split 2 of 5
# Training Encoder
# #########################################
# Epoch 1 of 20
# __Training__
# 2021-03-08 04:18:03
# MEAN LOSS: 0.7209640258789063
# __Validation__
# 2021-03-08 04:18:03
# MEAN LOSS: 0.7167265073980542
# #########################################
# Epoch 2 of 20
# __Training__
# 2021-03-08 04:18:03
# MEAN LOSS: 0.7155427795410156
# __Validation__
# 2021-03-08 04:18:03
# MEAN LOSS: 0.7119796849069673
# #########################################
# Epoch 3 of 20
# __Training__
# 2021-03-08 04:18:04
# MEAN LOSS: 0.711084375
# __Validation__
# 2021-03-08 04:18:04
# MEAN LOSS: 0.7081007249284499
# #########################################
# Epoch 4 of 20
# __Training__
# 2021-03-08 04:18:04
# MEAN LOSS: 0.7074416381835937
# __Validation__
# 2021-03-08 04:18:04
# MEAN LOSS: 0.7049399993099896
# #########################################
# Epoch 5 of 20
# __Training__
# 2021-03-08 04:18:04
# MEAN LOSS: 0.7044686614990234
# __Validation__
# 2021-03-08 04:18:05
# MEAN LOSS: 0.7023759253061537
# #########################################
# Epoch 6 of 20
# __Training__
# 2021-03-08 04:18:05
# MEAN LOSS: 0.7020546783447266
# __Validation__
# 2021-03-08 04:18:05
# MEAN LOSS: 0.7003158720413057
# #########################################
# Epoch 7 of 20
# __Training__
# 2021-03-08 04:18:05
# MEAN LOSS: 0.7001142303466796
# __Validation__
# 2021-03-08 04:18:06
# MEAN LOSS: 0.6986842185500288
# #########################################
# Epoch 8 of 20
# __Training__
# 2021-03-08 04:18:06
# MEAN LOSS: 0.6985765380859374
# __Validation__
# 2021-03-08 04:18:06
# MEAN LOSS: 0.6974152600196543
# #########################################
# Epoch 9 of 20
# __Training__
# 2021-03-08 04:18:06
# MEAN LOSS: 0.6973785034179687
# __Validation__
# 2021-03-08 04:18:07
# MEAN LOSS: 0.696447405055447
# #########################################
# Epoch 10 of 20
# __Training__
# 2021-03-08 04:18:07
# MEAN LOSS: 0.6964611114501953
# __Validation__
# 2021-03-08 04:18:07
# MEAN LOSS: 0.6957200923339404
# #########################################
# Epoch 11 of 20
# __Training__
# 2021-03-08 04:18:07
# MEAN LOSS: 0.6957665710449219
# __Validation__
# 2021-03-08 04:18:08
# MEAN LOSS: 0.6951744429814075
# #########################################
# Epoch 12 of 20
# __Training__
# 2021-03-08 04:18:08
# MEAN LOSS: 0.6952402801513672
# __Validation__
# 2021-03-08 04:18:08
# MEAN LOSS: 0.6947593723300552
# #########################################
# Epoch 13 of 20
# __Training__
# 2021-03-08 04:18:08
# MEAN LOSS: 0.6948352233886719
# __Validation__
# 2021-03-08 04:18:09
# MEAN LOSS: 0.694434831208951
# #########################################
# Epoch 14 of 20
# __Training__
# 2021-03-08 04:18:09
# MEAN LOSS: 0.6945141479492187
# __Validation__
# 2021-03-08 04:18:09
# MEAN LOSS: 0.6941723896510745
# #########################################
# Epoch 15 of 20
# __Training__
# 2021-03-08 04:18:09
# MEAN LOSS: 0.694253140258789
# __Validation__
# 2021-03-08 04:18:10
# MEAN LOSS: 0.6939584232471099
# #########################################
# Epoch 16 of 20
# __Training__
# 2021-03-08 04:18:10
# MEAN LOSS: 0.6940378997802734
# __Validation__
# 2021-03-08 04:18:10
# MEAN LOSS: 0.6937809969046221
# #########################################
# Epoch 17 of 20
# __Training__
# 2021-03-08 04:18:10
# MEAN LOSS: 0.6938549987792969
# __Validation__
# 2021-03-08 04:18:11
# MEAN LOSS: 0.6936284021468553
# #########################################
# Epoch 18 of 20
# __Training__
# 2021-03-08 04:18:11
# MEAN LOSS: 0.6936968627929687
# __Validation__
# 2021-03-08 04:18:11
# MEAN LOSS: 0.693499629503966
# #########################################
# Epoch 19 of 20
# __Training__
# 2021-03-08 04:18:11
# MEAN LOSS: 0.6935599334716797
# __Validation__
# 2021-03-08 04:18:12
# MEAN LOSS: 0.6933899269138339
# #########################################
# Epoch 20 of 20
# __Training__
# 2021-03-08 04:18:12
# MEAN LOSS: 0.6934401214599609
# __Validation__
# 2021-03-08 04:18:12
# MEAN LOSS: 0.693294604118615
# #########################################
# Finished
# 2021-03-08 04:18:12
# Running for split 3 of 5
# Training Encoder
# #########################################
# Epoch 1 of 20
# __Training__
# 2021-03-08 04:18:13
# MEAN LOSS: 0.7214844848632812
# __Validation__
# 2021-03-08 04:18:13
# MEAN LOSS: 0.7169979929816712
# #########################################
# Epoch 2 of 20
# __Training__
# 2021-03-08 04:18:13
# MEAN LOSS: 0.7160235229492188
# __Validation__
# 2021-03-08 04:18:14
# MEAN LOSS: 0.7121946607807753
# #########################################
# Epoch 3 of 20
# __Training__
# 2021-03-08 04:18:14
# MEAN LOSS: 0.7115162139892578
# __Validation__
# 2021-03-08 04:18:14
# MEAN LOSS: 0.7082754250156461
# #########################################
# Epoch 4 of 20
# __Training__
# 2021-03-08 04:18:14
# MEAN LOSS: 0.7078255096435547
# __Validation__
# 2021-03-08 04:18:15
# MEAN LOSS: 0.7050817920537171
# #########################################
# Epoch 5 of 20
# __Training__
# 2021-03-08 04:18:15
# MEAN LOSS: 0.7048075225830078
# __Validation__
# 2021-03-08 04:18:15
# MEAN LOSS: 0.7024872622760323
# #########################################
# Epoch 6 of 20
# __Training__
# 2021-03-08 04:18:15
# MEAN LOSS: 0.7023513366699219
# __Validation__
# 2021-03-08 04:18:15
# MEAN LOSS: 0.7003963824116787
# #########################################
# Epoch 7 of 20
# __Training__
# 2021-03-08 04:18:16
# MEAN LOSS: 0.7003714019775391
# __Validation__
# 2021-03-08 04:18:16
# MEAN LOSS: 0.6987328447810601
# #########################################
# Epoch 8 of 20
# __Training__
# 2021-03-08 04:18:16
# MEAN LOSS: 0.6987972229003906
# __Validation__
# 2021-03-08 04:18:16
# MEAN LOSS: 0.6974322561955902
# #########################################
# Epoch 9 of 20
# __Training__
# 2021-03-08 04:18:16
# MEAN LOSS: 0.6975661041259765
# __Validation__
# 2021-03-08 04:18:17
# MEAN LOSS: 0.6964334578904667
# #########################################
# Epoch 10 of 20
# __Training__
# 2021-03-08 04:18:17
# MEAN LOSS: 0.696618588256836
# __Validation__
# 2021-03-08 04:18:17
# MEAN LOSS: 0.6956798783516047
# #########################################
# Epoch 11 of 20
# __Training__
# 2021-03-08 04:18:17
# MEAN LOSS: 0.6958967376708984
# __Validation__
# 2021-03-08 04:18:18
# MEAN LOSS: 0.6951169375360388
# #########################################
# Epoch 12 of 20
# __Training__
# 2021-03-08 04:18:18
# MEAN LOSS: 0.6953461059570313
# __Validation__
# 2021-03-08 04:18:18
# MEAN LOSS: 0.6946951576871554
# #########################################
# Epoch 13 of 20
# __Training__
# 2021-03-08 04:18:18
# MEAN LOSS: 0.6949201385498047
# __Validation__
# 2021-03-08 04:18:19
# MEAN LOSS: 0.6943733084856337
# #########################################
# Epoch 14 of 20
# __Training__
# 2021-03-08 04:18:19
# MEAN LOSS: 0.6945832977294922
# __Validation__
# 2021-03-08 04:18:19
# MEAN LOSS: 0.6941210302976099
# #########################################
# Epoch 15 of 20
# __Training__
# 2021-03-08 04:18:19
# MEAN LOSS: 0.6943103149414063
# __Validation__
# 2021-03-08 04:18:20
# MEAN LOSS: 0.6939173577391919
# #########################################
# Epoch 16 of 20
# __Training__
# 2021-03-08 04:18:20
# MEAN LOSS: 0.6940837188720703
# __Validation__
# 2021-03-08 04:18:20
# MEAN LOSS: 0.6937497308080417
# #########################################
# Epoch 17 of 20
# __Training__
# 2021-03-08 04:18:20
# MEAN LOSS: 0.6938918640136719
# __Validation__
# 2021-03-08 04:18:21
# MEAN LOSS: 0.6936082539528367
# #########################################
# Epoch 18 of 20
# __Training__
# 2021-03-08 04:18:21
# MEAN LOSS: 0.693726318359375
# __Validation__
# 2021-03-08 04:18:21
# MEAN LOSS: 0.6934860325632173
# #########################################
# Epoch 19 of 20
# __Training__
# 2021-03-08 04:18:21
# MEAN LOSS: 0.6935806762695312
# __Validation__
# 2021-03-08 04:18:22
# MEAN LOSS: 0.693377854478563
# #########################################
# Epoch 20 of 20
# __Training__
# 2021-03-08 04:18:22
# MEAN LOSS: 0.6934501678466797
# __Validation__
# 2021-03-08 04:18:22
# MEAN LOSS: 0.6932799633723138
# #########################################
# Finished
# 2021-03-08 04:18:22
# Running for split 4 of 5
# Training Encoder
# #########################################
# Epoch 1 of 20
# __Training__
# 2021-03-08 04:18:23
# MEAN LOSS: 0.7212020080566406
# __Validation__
# 2021-03-08 04:18:23
# MEAN LOSS: 0.7163453466928724
# #########################################
# Epoch 2 of 20
# __Training__
# 2021-03-08 04:18:23
# MEAN LOSS: 0.7157202270507812
# __Validation__
# 2021-03-08 04:18:24
# MEAN LOSS: 0.7116822277930918
# #########################################
# Epoch 3 of 20
# __Training__
# 2021-03-08 04:18:24
# MEAN LOSS: 0.7112114990234375
# __Validation__
# 2021-03-08 04:18:24
# MEAN LOSS: 0.7078681760387953
# #########################################
# Epoch 4 of 20
# __Training__
# 2021-03-08 04:18:24
# MEAN LOSS: 0.7075285217285157
# __Validation__
# 2021-03-08 04:18:25
# MEAN LOSS: 0.70475846641671
# #########################################
# Epoch 5 of 20
# __Training__
# 2021-03-08 04:18:25
# MEAN LOSS: 0.7045221893310547
# __Validation__
# 2021-03-08 04:18:25
# MEAN LOSS: 0.7022342081009859
# #########################################
# Epoch 6 of 20
# __Training__
# 2021-03-08 04:18:25
# MEAN LOSS: 0.7020791381835938
# __Validation__
# 2021-03-08 04:18:26
# MEAN LOSS: 0.700204040637218
# #########################################
# Epoch 7 of 20
# __Training__
# 2021-03-08 04:18:26
# MEAN LOSS: 0.7001130554199219
# __Validation__
# 2021-03-08 04:18:26
# MEAN LOSS: 0.6985942864611168
# #########################################
# Epoch 8 of 20
# __Training__
# 2021-03-08 04:18:26
# MEAN LOSS: 0.6985536865234375
# __Validation__
# 2021-03-08 04:18:26
# MEAN LOSS: 0.697341967015305
# #########################################
# Epoch 9 of 20
# __Training__
# 2021-03-08 04:18:27
# MEAN LOSS: 0.6973396789550781
# __Validation__
# 2021-03-08 04:18:27
# MEAN LOSS: 0.6963887459302571
# #########################################
# Epoch 10 of 20
# __Training__
# 2021-03-08 04:18:27
# MEAN LOSS: 0.696413134765625
# __Validation__
# 2021-03-08 04:18:27
# MEAN LOSS: 0.6956768156063653
# #########################################
# Epoch 11 of 20
# __Training__
# 2021-03-08 04:18:27
# MEAN LOSS: 0.6957170715332032
# __Validation__
# 2021-03-08 04:18:28
# MEAN LOSS: 0.695151314447851
# #########################################
# Epoch 12 of 20
# __Training__
# 2021-03-08 04:18:28
# MEAN LOSS: 0.695196484375
# __Validation__
# 2021-03-08 04:18:28
# MEAN LOSS: 0.6947600590442345
# #########################################
# Epoch 13 of 20
# __Training__
# 2021-03-08 04:18:28
# MEAN LOSS: 0.694802505493164
# __Validation__
# 2021-03-08 04:18:29
# MEAN LOSS: 0.6944639684915758
# #########################################
# Epoch 14 of 20
# __Training__
# 2021-03-08 04:18:29
# MEAN LOSS: 0.6944964782714844
# __Validation__
# 2021-03-08 04:18:29
# MEAN LOSS: 0.6942310213076972
# #########################################
# Epoch 15 of 20
# __Training__
# 2021-03-08 04:18:29
# MEAN LOSS: 0.6942532958984375
# __Validation__
# 2021-03-08 04:18:30
# MEAN LOSS: 0.6940419002227372
# #########################################
# Epoch 16 of 20
# __Training__
# 2021-03-08 04:18:30
# MEAN LOSS: 0.694055224609375
# __Validation__
# 2021-03-08 04:18:30
# MEAN LOSS: 0.6938797120678865
# #########################################
# Epoch 17 of 20
# __Training__
# 2021-03-08 04:18:30
# MEAN LOSS: 0.6938916442871094
# __Validation__
# 2021-03-08 04:18:31
# MEAN LOSS: 0.6937394575639204
# #########################################
# Epoch 18 of 20
# __Training__
# 2021-03-08 04:18:31
# MEAN LOSS: 0.6937518951416015
# __Validation__
# 2021-03-08 04:18:31
# MEAN LOSS: 0.693616281641592
# #########################################
# Epoch 19 of 20
# __Training__
# 2021-03-08 04:18:31
# MEAN LOSS: 0.6936298522949219
# __Validation__
# 2021-03-08 04:18:32
# MEAN LOSS: 0.6935088383411095
# #########################################
# Epoch 20 of 20
# __Training__
# 2021-03-08 04:18:32
# MEAN LOSS: 0.6935212371826172
# __Validation__
# 2021-03-08 04:18:32
# MEAN LOSS: 0.6934128288317113
# #########################################
# Finished
# 2021-03-08 04:18:32
# Running for split 5 of 5
# Training Encoder
# #########################################
# Epoch 1 of 20
# __Training__
# 2021-03-08 04:18:33
# MEAN LOSS: 0.721211474609375
# __Validation__
# 2021-03-08 04:18:33
# MEAN LOSS: 0.7171906369103708
# #########################################
# Epoch 2 of 20
# __Training__
# 2021-03-08 04:18:33
# MEAN LOSS: 0.7158311828613281
# __Validation__
# 2021-03-08 04:18:34
# MEAN LOSS: 0.7123672045854488
# #########################################
# Epoch 3 of 20
# __Training__
# 2021-03-08 04:18:34
# MEAN LOSS: 0.7113829284667968
# __Validation__
# 2021-03-08 04:18:34
# MEAN LOSS: 0.7084296953560102
# #########################################
# Epoch 4 of 20
# __Training__
# 2021-03-08 04:18:34
# MEAN LOSS: 0.7077358154296876
# __Validation__
# 2021-03-08 04:18:35
# MEAN LOSS: 0.7052198284708842
# #########################################
# Epoch 5 of 20
# __Training__
# 2021-03-08 04:18:35
# MEAN LOSS: 0.7047522338867187
# __Validation__
# 2021-03-08 04:18:35
# MEAN LOSS: 0.702610829625443
# #########################################
# Epoch 6 of 20
# __Training__
# 2021-03-08 04:18:35
# MEAN LOSS: 0.7023248992919922
# __Validation__
# 2021-03-08 04:18:36
# MEAN LOSS: 0.7005070738702288
# #########################################
# Epoch 7 of 20
# __Training__
# 2021-03-08 04:18:36
# MEAN LOSS: 0.7003697906494141
# __Validation__
# 2021-03-08 04:18:36
# MEAN LOSS: 0.6988323084627799
# #########################################
# Epoch 8 of 20
# __Training__
# 2021-03-08 04:18:36
# MEAN LOSS: 0.6988157440185547
# __Validation__
# 2021-03-08 04:18:37
# MEAN LOSS: 0.6975201968133825
# #########################################
# Epoch 9 of 20
# __Training__
# 2021-03-08 04:18:37
# MEAN LOSS: 0.6975977508544922
# __Validation__
# 2021-03-08 04:18:37
# MEAN LOSS: 0.6965087561002195
# #########################################
# Epoch 10 of 20
# __Training__
# 2021-03-08 04:18:37
# MEAN LOSS: 0.6966532684326172
# __Validation__
# 2021-03-08 04:18:38
# MEAN LOSS: 0.6957382284554139
# #########################################
# Epoch 11 of 20
# __Training__
# 2021-03-08 04:18:38
# MEAN LOSS: 0.6959232666015625
# __Validation__
# 2021-03-08 04:18:38
# MEAN LOSS: 0.6951534226603813
# #########################################
# Epoch 12 of 20
# __Training__
# 2021-03-08 04:18:38
# MEAN LOSS: 0.6953552978515625
# __Validation__
# 2021-03-08 04:18:39
# MEAN LOSS: 0.6947069829053217
# #########################################
# Epoch 13 of 20
# __Training__
# 2021-03-08 04:18:39
# MEAN LOSS: 0.6949064697265624
# __Validation__
# 2021-03-08 04:18:39
# MEAN LOSS: 0.6943606935461613
# #########################################
# Epoch 14 of 20
# __Training__
# 2021-03-08 04:18:39
# MEAN LOSS: 0.6945450103759766
# __Validation__
# 2021-03-08 04:18:39
# MEAN LOSS: 0.6940882190941262
# #########################################
# Epoch 15 of 20
# __Training__
# 2021-03-08 04:18:40
# MEAN LOSS: 0.6942501770019531
# __Validation__
# 2021-03-08 04:18:40
# MEAN LOSS: 0.6938709564621013
# #########################################
# Epoch 16 of 20
# __Training__
# 2021-03-08 04:18:40
# MEAN LOSS: 0.6940063659667969
# __Validation__
# 2021-03-08 04:18:40
# MEAN LOSS: 0.6936917446627475
# #########################################
# Epoch 17 of 20
# __Training__
# 2021-03-08 04:18:40
# MEAN LOSS: 0.6938009521484375
# __Validation__
# 2021-03-08 04:18:41
# MEAN LOSS: 0.6935436616171383
# #########################################
# Epoch 18 of 20
# __Training__
# 2021-03-08 04:18:41
# MEAN LOSS: 0.6936270599365234
# __Validation__
# 2021-03-08 04:18:41
# MEAN LOSS: 0.6934172924738763
# #########################################
# Epoch 19 of 20
# __Training__
# 2021-03-08 04:18:41
# MEAN LOSS: 0.6934755706787109
# __Validation__
# 2021-03-08 04:18:42
# MEAN LOSS: 0.6933034352629599
# #########################################
# Epoch 20 of 20
# __Training__
# 2021-03-08 04:18:42
# MEAN LOSS: 0.6933392364501954
# __Validation__
# 2021-03-08 04:18:42
# MEAN LOSS: 0.6931984297978138
# #########################################
# Finished
# 2021-03-08 04:18:42

# %%
scores_df = pd.DataFrame({'score': MyMultiTrainTester.train_scores, 'stage' : np.repeat('train', n_splits)})
scores_df = scores_df.append(pd.DataFrame({'score': MyMultiTrainTester.test_scores, 'stage' : np.repeat('test', n_splits)}))
scores_df
# Out:
#       score  stage
# 0  0.653750  train
# 1  0.733437  train
# 2  0.637813  train
# 3  0.690625  train
# 4  0.647188  train
# 0  0.670000   test
# 1  0.732500   test
# 2  0.596250   test
# 3  0.685000   test
# 4  0.623750   test

# %%
sns.boxplot(data = scores_df, x = 'stage', y = 'score')
# Out:
# <AxesSubplot:xlabel='stage', ylabel='score'>

# %%
MyMultiTrainTester.plot_class_freq(normalize=True)

# %%
MyMultiTrainTester.plot_confusion(normalize=True)

# %%
for i, trainer in enumerate(MyMultiTrainTester.TrainerList):
    plt.figure(i)
    print(sns.lineplot(data=trainer.model.TrainStats, x='epoch', y='mean_loss', hue = 'stage'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ### Examine Data In Encoded Space

# %%
Trainer_use = MyMultiTrainTester.TrainerList[0]

# %%
X_transform = Trainer_use.transform_X(X)

# %%
X_encoded = Trainer_use.model.model.forward(torch.from_numpy(X_transform).to(torch.float32)).detach().numpy()

# %%
# X_encoded = MyFeedForward.forward(torch.from_numpy(X_transform).to(torch.float32)).detach().numpy()

# %%
X_encoded.shape
# Out:
# (4000, 2)

# %%
y_label = Trainer_use.model.one_hot.inverse_transform(y).astype('str')

# %%
y_pred = Trainer_use.model.predict(X_transform)
y_pred = Trainer_use.model.one_hot.inverse_transform(y_pred).astype('str')

# %%
X_enc_df = pd.DataFrame(X_encoded, columns = ['X' + str(i+1) for i in range(X_encoded.shape[1])])
X_enc_df['y'] = y_label
X_enc_df['y_pred'] = y_pred

# %%
X_enc_df
# Out:
#             X1        X2  y y_pred
# 0     0.273021  0.629435  0      1
# 1     0.230647  0.758729  1      1
# 2     0.365694  0.660010  0      1
# 3     0.136957  0.758362  1      1
# 4     0.384796  0.717636  1      0
# ...        ...       ... ..    ...
# 3995  0.475579  0.707656  0      0
# 3996  0.514486  0.724515  0      0
# 3997  0.507030  0.682309  0      0
# 3998  0.292708  0.758128  1      1
# 3999  0.408762  0.717812  1      0
#
# [4000 rows x 4 columns]

# %%
sns.displot(data=X_enc_df, x='X1', hue='y')

# %%
sns.displot(data=X_enc_df, x='X2', hue='y')

# %%
def do_plot(df, x, y, hue):
    if x in df.columns and y in df.columns and hue in df.columns:
        sns.scatterplot(data=df, x=x, y=y, hue = hue)

# %%
do_plot(X_enc_df, 'X1', 'X2', 'y')

# %%
do_plot(X_enc_df, 'X1', 'X2', 'y_pred')

# %%
do_plot(X_enc_df, 'X2', 'X3', 'y')

# %%
do_plot(X_enc_df, 'X3', 'X4', 'y')

# %% [markdown]
# ### Examine Data In Original Space

# %%
X_df = pd.DataFrame(X, columns = ['X1', 'X2'])
X_df['y'] = y_label

# %%
sns.scatterplot(data=X_df, x='X1', y='X2', hue = 'y')
# Out:
# <AxesSubplot:xlabel='X1', ylabel='X2'>
