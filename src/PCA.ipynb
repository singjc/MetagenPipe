# %%
from sklearn import model_selection
from sklearn import metrics
import os
import numpy as np
import pandas as pd
from MicroBiome import MicroBiomeDataSet, Trainer, TrainTester, MultiTrainTester
from sklearn import linear_model as LM
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import copy

# %% [markdown]
# # Load Data

# %%
top_dir = '/project'
data_dir = os.path.join(top_dir, 'data')
preproc_dir = os.path.join(data_dir, 'preprocessed')
inp_dir = os.path.join(preproc_dir, 'Gupta_2020_Precompiled_Cleaned')

# %%
os.listdir(inp_dir)
# Out:
# ['MatrixDataClean.csv', 'SampleMetaDataClean.csv', 'FeatMetaDataClean.csv']

# %%
MatrixData = np.loadtxt(os.path.join(inp_dir, 'MatrixDataClean.csv'))
MatrixData.shape
# Out:
# (4347, 903)

# %%
SampleMeta = pd.read_csv(os.path.join(inp_dir, 'SampleMetaDataClean.csv'))
SampleMeta
# Out:
#       Unnamed: 0  Unnamed: 0.1               6            study  \
# 0              0             0  SAMEA104142287         V-2_ACVD
# 1              1             1  SAMEA104142288         V-2_ACVD
# 2              2             2  SAMEA104142293         V-2_ACVD
# 3              3             3  SAMEA104142291         V-2_ACVD
# 4              4             4  SAMEA104142284         V-2_ACVD
# ...          ...           ...             ...              ...
# 4342        4342          4342    SAMEA4431948  S-7_Underweight
# 4343        4343          4343    SAMEA4431949  S-7_Underweight
# 4344        4344          4344    SAMEA4431951  S-7_Underweight
# 4345        4345          4345    SAMEA4431964  S-7_Underweight
# 4346        4346          4346    SAMEA4431982  S-7_Underweight
#
#      Study No. (From VG sheet (V-*) from SB sheet (S-*))  \
# 0                                                   V-2
# 1                                                   V-2
# 2                                                   V-2
# 3                                                   V-2
# 4                                                   V-2
# ...                                                 ...
# 4342                                                S-7
# 4343                                                S-7
# 4344                                                S-7
# 4345                                                S-7
# 4346                                                S-7
#
#                                          Title of Paper Author (year)  \
# 0     The gut microbiome in atherosclerotic cardiova...    Jie (2017)
# 1     The gut microbiome in atherosclerotic cardiova...    Jie (2017)
# 2     The gut microbiome in atherosclerotic cardiova...    Jie (2017)
# 3     The gut microbiome in atherosclerotic cardiova...    Jie (2017)
# 4     The gut microbiome in atherosclerotic cardiova...    Jie (2017)
# ...                                                 ...           ...
# 4342  Two distinct metacommunities characterize the ...     He (2017)
# 4343  Two distinct metacommunities characterize the ...     He (2017)
# 4344  Two distinct metacommunities characterize the ...     He (2017)
# 4345  Two distinct metacommunities characterize the ...     He (2017)
# 4346  Two distinct metacommunities characterize the ...     He (2017)
#
#                     Journal Study Accession Sample Accession or Sample ID  \
# 0     Nature communications      PRJEB21528                SAMEA104142287
# 1     Nature communications      PRJEB21528                SAMEA104142288
# 2     Nature communications      PRJEB21528                SAMEA104142293
# 3     Nature communications      PRJEB21528                SAMEA104142291
# 4     Nature communications      PRJEB21528                SAMEA104142284
# ...                     ...             ...                           ...
# 4342            Gigascience      PRJEB15371                  SAMEA4431948
# 4343            Gigascience      PRJEB15371                  SAMEA4431949
# 4344            Gigascience      PRJEB15371                  SAMEA4431951
# 4345            Gigascience      PRJEB15371                  SAMEA4431964
# 4346            Gigascience      PRJEB15371                  SAMEA4431982
#
#       ... Alcohol Consumption (Yes/No) Diet1 Intervention for study (Diet)  \
# 0     ...                          NaN   NaN                           NaN
# 1     ...                          NaN   NaN                           NaN
# 2     ...                          NaN   NaN                           NaN
# 3     ...                          NaN   NaN                           NaN
# 4     ...                          NaN   NaN                           NaN
# ...   ...                          ...   ...                           ...
# 4342  ...                          NaN   NaN                            No
# 4343  ...                          NaN   NaN                            No
# 4344  ...                          NaN   NaN                            No
# 4345  ...                          NaN   NaN                            No
# 4346  ...                          NaN   NaN                            No
#
#      Intervention for study (medication)  Sequencing Platform  \
# 0                                    NaN  Illumina HiSeq 2000
# 1                                    NaN  Illumina HiSeq 2000
# 2                                    NaN  Illumina HiSeq 2000
# 3                                    NaN  Illumina HiSeq 2000
# 4                                    NaN  Illumina HiSeq 2000
# ...                                  ...                  ...
# 4342                                  No  Illumina HiSeq 2000
# 4343                                  No  Illumina HiSeq 2000
# 4344                                  No  Illumina HiSeq 2000
# 4345                                  No  Illumina HiSeq 2000
# 4346                                  No  Illumina HiSeq 2000
#
#      Library layout (SINGLE/PAIRED) Read count after Quality control  \
# 0                            PAIRED                       43356775.0
# 1                            PAIRED                       41073871.0
# 2                            PAIRED                       40199673.0
# 3                            PAIRED                       31054158.0
# 4                            PAIRED                       36081150.0
# ...                             ...                              ...
# 4342                         PAIRED                       52212493.0
# 4343                         PAIRED                       50635879.0
# 4344                         PAIRED                       40712962.0
# 4345                         PAIRED                       38177360.0
# 4346                         PAIRED                       43643399.0
#
#         Healthy age_group age_category
# 0     Unhealthy     40-50        adult
# 1     Unhealthy     70-80       senior
# 2     Unhealthy     70-80       senior
# 3     Unhealthy     40-50        adult
# 4     Unhealthy     60-70       senior
# ...         ...       ...          ...
# 4342  Unhealthy     10-20        child
# 4343  Unhealthy     10-20        child
# 4344  Unhealthy     10-20        child
# 4345  Unhealthy     10-20        youth
# 4346  Unhealthy     10-20        youth
#
# [4347 rows x 38 columns]

# %%
FeatMeta = pd.read_csv(os.path.join(inp_dir, 'FeatMetaDataClean.csv'))
FeatMeta
# Out:
#                               Unnamed: 0                              feature
# 0               s__Abiotrophia_defectiva             s__Abiotrophia_defectiva
# 1            s__Acetobacter_unclassified          s__Acetobacter_unclassified
# 2            s__Achromobacter_piechaudii          s__Achromobacter_piechaudii
# 3          s__Achromobacter_unclassified        s__Achromobacter_unclassified
# 4          s__Achromobacter_xylosoxidans        s__Achromobacter_xylosoxidans
# ..                                   ...                                  ...
# 898               s__Weissella_koreensis               s__Weissella_koreensis
# 899       s__Weissella_paramesenteroides       s__Weissella_paramesenteroides
# 900            s__Weissella_unclassified            s__Weissella_unclassified
# 901  s__Wohlfahrtiimonas_chitiniclastica  s__Wohlfahrtiimonas_chitiniclastica
# 902           s__Yersinia_enterocolitica           s__Yersinia_enterocolitica
#
# [903 rows x 2 columns]

# %% [markdown]
# # Run PCA

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(MatrixData)

# %%
pca_model = PCA(n_components = 100)

# %%
X_PCA = pca_model.fit_transform(X_scaled)

# %%
sns.lineplot(x = np.arange(1,101), y = pca_model.explained_variance_)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x = np.arange(1,21), y = pca_model.explained_variance_[0:20])
# Out:
# <AxesSubplot:>

# %%
pca_model.components_.shape
# Out:
# (100, 903)

# %%
heatmap_df = FeatMeta
for i in range(21):
    PC_name = 'PC' + str(i)
    heatmap_df[PC_name] = pca_model.components_[i,:]

heatmap_df.index = heatmap_df['feature']
heatmap_df.pop('Unnamed: 0')
heatmap_df.pop('feature')
heatmap_df
# Out:
#                                           PC0       PC1       PC2       PC3  \
# feature
# s__Abiotrophia_defectiva             0.006322 -0.000608  0.119331 -0.033013
# s__Acetobacter_unclassified         -0.000086 -0.000089 -0.001723  0.000618
# s__Achromobacter_piechaudii          0.000230 -0.000055  0.011601 -0.004321
# s__Achromobacter_unclassified        0.000218  0.001585  0.006202 -0.002211
# s__Achromobacter_xylosoxidans        0.000230 -0.000055  0.011601 -0.004321
# ...                                       ...       ...       ...       ...
# s__Weissella_koreensis               0.000037 -0.000112  0.003062  0.001169
# s__Weissella_paramesenteroides       0.000978 -0.000161  0.037401 -0.011227
# s__Weissella_unclassified            0.000197 -0.000193  0.015115 -0.005750
# s__Wohlfahrtiimonas_chitiniclastica -0.000000  0.000000 -0.000000  0.000000
# s__Yersinia_enterocolitica          -0.000000  0.000000 -0.000000  0.000000
#
#                                           PC4       PC5       PC6       PC7  \
# feature
# s__Abiotrophia_defectiva            -0.014632 -0.025066  0.004284 -0.004182
# s__Acetobacter_unclassified         -0.000362  0.000631 -0.001982 -0.000096
# s__Achromobacter_piechaudii         -0.005675 -0.001223 -0.003596  0.045014
# s__Achromobacter_unclassified       -0.008394  0.000695 -0.010153  0.351798
# s__Achromobacter_xylosoxidans       -0.005675 -0.001223 -0.003596  0.045014
# ...                                       ...       ...       ...       ...
# s__Weissella_koreensis              -0.000375  0.000749 -0.002662  0.000268
# s__Weissella_paramesenteroides      -0.004927 -0.017632  0.006681 -0.000329
# s__Weissella_unclassified           -0.008182  0.007582 -0.007904 -0.000528
# s__Wohlfahrtiimonas_chitiniclastica  0.000000 -0.000000  0.000000  0.000000
# s__Yersinia_enterocolitica           0.000000 -0.000000  0.000000  0.000000
#
#                                           PC8       PC9  ...      PC11  \
# feature                                                  ...
# s__Abiotrophia_defectiva            -0.017676  0.014311  ... -0.054459
# s__Acetobacter_unclassified         -0.000992  0.003371  ...  0.001558
# s__Achromobacter_piechaudii         -0.002538  0.004556  ...  0.005588
# s__Achromobacter_unclassified        0.004988  0.001514  ... -0.002674
# s__Achromobacter_xylosoxidans       -0.002538  0.004556  ...  0.005588
# ...                                       ...       ...  ...       ...
# s__Weissella_koreensis              -0.002771  0.003934  ...  0.013851
# s__Weissella_paramesenteroides      -0.015898  0.009127  ... -0.003983
# s__Weissella_unclassified           -0.002019 -0.013891  ...  0.001130
# s__Wohlfahrtiimonas_chitiniclastica  0.000000 -0.000000  ...  0.000000
# s__Yersinia_enterocolitica           0.000000 -0.000000  ...  0.000000
#
#                                          PC12      PC13      PC14      PC15  \
# feature
# s__Abiotrophia_defectiva             0.080411  0.067023 -0.042951 -0.042099
# s__Acetobacter_unclassified         -0.002780  0.002823 -0.003756  0.000412
# s__Achromobacter_piechaudii         -0.017134 -0.003808  0.005723  0.022758
# s__Achromobacter_unclassified        0.003603 -0.004593  0.006890  0.007690
# s__Achromobacter_xylosoxidans       -0.017134 -0.003808  0.005723  0.022758
# ...                                       ...       ...       ...       ...
# s__Weissella_koreensis              -0.012791  0.006111 -0.014204 -0.000031
# s__Weissella_paramesenteroides      -0.024693 -0.024907  0.022607 -0.033483
# s__Weissella_unclassified            0.001809 -0.000172  0.001016 -0.011072
# s__Wohlfahrtiimonas_chitiniclastica  0.000000  0.000000 -0.000000  0.000000
# s__Yersinia_enterocolitica           0.000000  0.000000 -0.000000  0.000000
#
#                                          PC16      PC17      PC18      PC19  \
# feature
# s__Abiotrophia_defectiva             0.019579  0.044561 -0.023795  0.004299
# s__Acetobacter_unclassified         -0.004157 -0.000598  0.000273 -0.000961
# s__Achromobacter_piechaudii         -0.047155 -0.033064  0.019971 -0.008355
# s__Achromobacter_unclassified       -0.007247 -0.006273  0.003244  0.000719
# s__Achromobacter_xylosoxidans       -0.047155 -0.033064  0.019971 -0.008355
# ...                                       ...       ...       ...       ...
# s__Weissella_koreensis              -0.002674  0.003015  0.005946 -0.000821
# s__Weissella_paramesenteroides      -0.007372 -0.071151 -0.003440 -0.008579
# s__Weissella_unclassified            0.013457 -0.010523 -0.000729 -0.000731
# s__Wohlfahrtiimonas_chitiniclastica -0.000000 -0.000000 -0.000000 -0.000000
# s__Yersinia_enterocolitica          -0.000000 -0.000000 -0.000000 -0.000000
#
#                                          PC20
# feature
# s__Abiotrophia_defectiva             0.018578
# s__Acetobacter_unclassified         -0.003192
# s__Achromobacter_piechaudii         -0.001514
# s__Achromobacter_unclassified        0.011198
# s__Achromobacter_xylosoxidans       -0.001514
# ...                                       ...
# s__Weissella_koreensis              -0.001347
# s__Weissella_paramesenteroides       0.041208
# s__Weissella_unclassified            0.001534
# s__Wohlfahrtiimonas_chitiniclastica -0.000000
# s__Yersinia_enterocolitica          -0.000000
#
# [903 rows x 21 columns]

# %%
sns.clustermap(heatmap_df)
# Out:
# /root/anaconda/envs/microbiome/lib/python3.7/site-packages/seaborn/matrix.py:649: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# Overall, we don't see super blocky strucutre

# %%
# get maximum PC loading
max_loading = np.array([np.max(pca_model.components_[:, i]) for i in range(pca_model.components_.shape[1])])

# %%
# distribution of maximum PC loadings across ~900 features
sns.displot(max_loading)

# %% [markdown]
# It seems like most features are at least somewhat important, while there are a handful that are really important to variation

# %%
heatmap_df['PC1'].sort_values(ascending = False)[0:40]
# Out:
# feature
# s__Riemerella_unclassified           0.199033
# s__Chryseobacterium_unclassified     0.198974
# s__Leucobacter_unclassified          0.198974
# s__Sphingobacterium_unclassified     0.198974
# s__Limnohabitans_unclassified        0.198974
# s__Verminephrobacter_unclassified    0.198974
# s__Thauera_phenylacetica             0.198974
# s__Delftia_acidovorans               0.198974
# s__Pseudoxanthomonas_unclassified    0.198974
# s__Methyloversatilis_unclassified    0.198974
# s__Pseudomonas_stutzeri              0.198974
# s__Pseudomonas_mendocina             0.198974
# s__Pseudomonas_nitroreducens         0.198974
# s__Pseudomonas_denitrificans         0.198974
# s__Myroides_unclassified             0.198974
# s__Arcobacter_unclassified           0.198877
# s__Pseudomonas_alcaligenes           0.198583
# s__Pseudomonas_unclassified          0.198462
# s__Acinetobacter_ursingii            0.198273
# s__Stenotrophomonas_unclassified     0.197892
# s__Brevundimonas_diminuta            0.197407
# s__Stenotrophomonas_maltophilia      0.197301
# s__Brevundimonas_unclassified        0.193855
# s__Alicycliphilus_unclassified       0.193523
# s__Alicycliphilus_denitrificans      0.179764
# s__Rhodococcus_erythropolis          0.106114
# s__Caulobacter_unclassified          0.079376
# s__Lysinibacillus_sphaericus         0.054457
# s__Cellulophaga_unclassified         0.033783
# s__Comamonas_unclassified            0.023960
# s__Lysinibacillus_unclassified       0.021637
# s__Shigella_flexneri                 0.016811
# s__Polaromonas_unclassified          0.012854
# s__Alistipes_putredinis              0.011686
# s__Enhydrobacter_aerosaccus          0.010232
# s__Arcobacter_butzleri               0.007410
# s__Barnesiella_intestinihominis      0.006852
# s__Alistipes_senegalensis            0.006122
# s__Eubacterium_cylindroides          0.005718
# s__Thauera_terpenica                 0.005673
# Name: PC1, dtype: float64

# %%
sns.displot(heatmap_df['PC1'])

# %%
sns.displot(heatmap_df['PC2'])

# %%
sns.displot(heatmap_df['PC3'])

# %%
sns.displot(heatmap_df['PC4'])

# %%
sns.displot(heatmap_df['PC5'])

# %% [markdown]
# Individual PCs tend to be dominated by a small minority of features

# %%
for i in range(0, 100):
    PC_name = 'PC' + str(i + 1)
    SampleMeta[PC_name] = X_PCA[:, i]

# %%
sns.scatterplot(data = SampleMeta, x = 'PC1', y = 'PC2', hue = 'Study Accession')
# Out:
# <AxesSubplot:xlabel='PC1', ylabel='PC2'>

# %%
sns.scatterplot(data = SampleMeta, x = 'PC2', y = 'PC3', hue = 'Healthy')

# %%
sns.scatterplot(data = SampleMeta, x = 'PC3', y = 'PC4', hue = 'Healthy')
# Out:
# <AxesSubplot:xlabel='PC3', ylabel='PC4'>

# %%
sns.scatterplot(data = SampleMeta, x = 'PC4', y = 'PC5', hue = 'Healthy')

# %%
sns.scatterplot(data = SampleMeta, x = 'PC15', y = 'PC16', hue = 'Healthy')
# Out:
# <AxesSubplot:xlabel='PC15', ylabel='PC16'>

# %%
sns.scatterplot(data = SampleMeta, x = 'PC17', y = 'PC18', hue = 'Healthy')
# Out:
# <AxesSubplot:xlabel='PC17', ylabel='PC18'>

# %%
sns.scatterplot(data = SampleMeta, x = 'PC19', y = 'PC20', hue = 'Healthy')

# %% [markdown]
# Overall, it doesn't appear that health status really as too much to do with the first few PCs, although picture becomes more interesting at higher PCs. First few PCs look to be outlier effects TODO: Train LR model that just uses PCA results, or try KNN

# %%
heatmap_df_samples = SampleMeta[['Healthy', 'Phenotype']]
pc_cols = np.array(['PC' + str(i + 1) for i in range(0,20)])
for pc in pc_cols:
    heatmap_df_samples[pc] = SampleMeta[pc]
    
heatmap_df_samples
# Out:
# /root/anaconda/envs/microbiome/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#         Healthy    Phenotype       PC1       PC2        PC3       PC4  \
# 0     Unhealthy         ACVD  1.784576 -0.232666  29.790850 -6.572769
# 1     Unhealthy         ACVD  0.243618 -0.132562   2.954659 -0.053701
# 2     Unhealthy         ACVD -0.180335 -0.113250   0.738989 -0.139017
# 3     Unhealthy         ACVD  0.058698 -0.110921   5.267182 -1.047231
# 4     Unhealthy         ACVD  0.599145 -0.180566   6.088577 -2.025676
# ...         ...          ...       ...       ...        ...       ...
# 4342  Unhealthy  Underweight -0.057634 -0.146836   4.010571 -1.363476
# 4343  Unhealthy  Underweight -0.200779 -0.061295  -1.185960  0.241116
# 4344  Unhealthy  Underweight -0.189474 -0.025933   0.127366 -0.144253
# 4345  Unhealthy  Underweight -0.246452 -0.105735  -0.645939  0.129714
# 4346  Unhealthy  Underweight -0.155655 -0.035620  -0.305565  0.070129
#
#            PC5       PC6       PC7       PC8  ...      PC11      PC12  \
# 0    -2.653574 -5.801088  1.153820 -0.670039  ... -1.916240 -6.648084
# 1     1.470880 -3.532588  1.877072  0.069204  ...  0.692400  4.927800
# 2     0.600442 -2.056210  1.320835 -0.098215  ...  0.739522 -0.186255
# 3    -0.941230 -1.141590 -0.165357 -0.006397  ...  0.590453 -1.733510
# 4    -1.100533  0.304291 -0.154168 -0.440644  ... -0.224447  0.000973
# ...        ...       ...       ...       ...  ...       ...       ...
# 4342 -0.514209 -2.105568  0.971657 -0.207070  ...  1.200581 -0.375933
# 4343  1.171299 -2.116357  1.439750 -0.061254  ...  0.066333 -0.653314
# 4344 -1.074582  1.462347 -0.921931 -0.043197  ...  0.161843  0.476624
# 4345  0.972356 -2.194304  1.373658 -0.136886  ...  0.463331 -0.503853
# 4346  0.425480 -1.093478  0.746839 -0.020274  ...  0.261285 -0.141916
#
#           PC13      PC14      PC15      PC16      PC17      PC18      PC19  \
# 0     0.696971 -7.478313  6.372286 -8.147826  9.428580 -6.547975  7.866899
# 1    -2.235110  1.215884 -3.264441  1.866417 -1.006320  2.903712  3.438822
# 2    -0.663563  1.023332 -0.144822 -0.536329  0.420144  1.507209 -0.772994
# 3     2.611424  4.845247 -2.224233  1.003971 -3.998754 -1.921070 -0.355469
# 4     0.625136 -1.012649  0.263119 -0.689325  4.738592  2.309896  0.271403
# ...        ...       ...       ...       ...       ...       ...       ...
# 4342 -0.293942  0.366575  0.918775 -2.167964  1.954555  0.360690 -1.168509
# 4343  0.439817 -0.254482  0.180804  0.148140  0.066037  0.287053 -0.434453
# 4344 -0.407984  0.710101 -0.138992  0.090159 -0.440900  0.405734  0.368297
# 4345 -0.300473  0.522431  0.103595 -0.649960  0.257175  0.863250 -0.871652
# 4346 -0.240647  0.425304  0.089158  0.247798 -0.472995  0.733354 -0.372449
#
#           PC20
# 0     1.057340
# 1     0.621139
# 2    -0.004675
# 3    -0.646607
# 4     1.047130
# ...        ...
# 4342  0.225717
# 4343  0.302202
# 4344  0.247905
# 4345  0.200033
# 4346 -0.003172
#
# [4347 rows x 22 columns]

# %%
healthy = heatmap_df_samples.pop('Healthy')
pheno = heatmap_df_samples.pop('Phenotype')

# %%
lut_healthy = dict(zip(healthy.unique(), 'rg'))
row_colors_health = healthy.map(lut_healthy)
sns.clustermap(heatmap_df_samples, row_colors=row_colors_health, vmin = -5, vmax = 5)
# Out:
# /root/anaconda/envs/microbiome/lib/python3.7/site-packages/seaborn/matrix.py:649: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
lut_healthy
# Out:
# {'Unhealthy': 'r', 'Healthy': 'g'}

# %%
np.mean(heatmap_df_samples.iloc[0:1000, :].to_numpy())
# Out:
# 0.047326137094688366

# %%
np.std(heatmap_df_samples.iloc[0:1000, :].to_numpy())
# Out:
# 3.343913285826335

# %% [markdown]
# It doesn't look like healthy samples cleanly cluster on their own in PCA space. This may be part of the reason why getting above 70% balanced accuracy is difficult

# %%
sns.clustermap(heatmap_df_samples[['PC3', 'PC4', 'PC5', 'PC6', 'PC7']], row_colors=row_colors_health, vmin = -5, vmax = 5)
